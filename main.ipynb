# %% [markdown]
# # COMP 333 — Final Project: Phase 1
# ## Data Acquisition, Exploration & Baseline Model
#
# **Dataset:**
# **Source:**
# | Name | Student ID | Contribution |
# |------|-----------|---------------|
# | Gorden | 40263250 | [Describe contributions] |
# | [Teammate] | [ID] | [Describe contributions] |
#
# ---

# %% [markdown]
# ## 1. Setup & Imports

# %%
# core libraries
import pandas as pd
import numpy as np
from scipy import stats

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %%
df = pd.read_csv('Data/combined.csv', low_memory=False)

# %%
ax = df['ArrDelay'].hist(bins=50, color='steelblue', edgecolor='black')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.xlim(-100, 500)
plt.show()
